# %%
import os
import sys
# !git clone https://github.com/ifzhang/ByteTrack.git #
# %cd {os.getcwd()}{os.sep}ByteTrack
# !pip install -q -r requirements.txt
# !python3 setup.py -q develop
# !pip install -q loguru lap
sys.path.append(f"{os.getcwd()}{os.sep}ByteTrack")
# %cd .
# Out:
# c:\Users\swaminathan.ayyappan\Documents\Projects_new\AI-Sales-Demonstration-\Grape_detection_and_tracking\ByteTrack
# Cloning into 'ByteTrack'...
# Updating files:   3% (8/229)
# Updating files:   3% (9/229)
# Updating files:   4% (10/229)
# Updating files:   5% (12/229)
# Updating files:   6% (14/229)
# Updating files:   7% (17/229)
# Updating files:   8% (19/229)
# Updating files:   9% (21/229)
# Updating files:  10% (23/229)
# Updating files:  11% (26/229)
# Updating files:  12% (28/229)
# Updating files:  13% (30/229)
# Updating files:  14% (33/229)
# Updating files:  15% (35/229)
# Updating files:  16% (37/229)
# Updating files:  17% (39/229)
# Updating files:  18% (42/229)
# Updating files:  19% (44/229)
# Updating files:  20% (46/229)
# Updating files:  21% (49/229)
# Updating files:  22% (51/229)
# Updating files:  23% (53/229)
# Updating files:  24% (55/229)
# Updating files:  25% (58/229)
# Updating files:  26% (60/229)
# Updating files:  27% (62/229)
# ...

# %%
#Test import to ensure byte_track and cython_bbox are successfully imported
from ByteTrack.yolox.tracker.byte_tracker import BYTETracker,STrack

# %%
import os
from grape_detection_tracking_inference import GrapeDetectTrack
user_input = input("Enter a path of a video file : ")
print(GrapeDetectTrack(input_video_file_path = user_input).perform_tracking_detection())
# Out:
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
# 2023-06-16 21:23:16,455 INFO grape_detection_tracking_inference  Video file received starting grape detection and trackings
# c:\Users\swaminathan.ayyappan\Documents\Projects_new\AI-Sales-Demonstration-\Grape_detection_and_tracking\Detections\DEkOw_result.mp4
# 2023-06-16 21:23:16,722 INFO grape_detection_tracking_inference  433 has been identified in the input video file
#   0%|          | 0/433 [00:00<?, ?it/s]
# 0: 384x640 (no detections), 1797.1ms
# Speed: 27.7ms preprocess, 1797.1ms inference, 20.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 1620.6ms
# Speed: 7.0ms preprocess, 1620.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 1579.1ms
# Speed: 7.0ms preprocess, 1579.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 1615.5ms
# ...
